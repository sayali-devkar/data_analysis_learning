# %%
import pandas as pd

# %%
df = pd.read_csv("netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## **1. EDA**

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 3.9 MB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %% [markdown]
# ## **2. Data Cleaning**

# %%
# coverting the date column to actual date column 
df['date_added'] = pd.to_datetime(df['date_added'], format='mixed')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   datetime64[us]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: datetime64[us](1), int64(1), str(10)
# memory usage: 3.7 MB

# %%
# handeling missing values 
df['director'] = df['director'].fillna('Unknown')
df['cast'] = df['cast'].fillna('Unknown')
df['country'] = df['country'].fillna('Unknown')
df.dropna(subset = ["date_added" , "rating" , "duration"] , inplace = True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# ## **1. Count how many Movies vs TV Shows are there**

# %%
df["type"].value_counts()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %% [markdown]
# ## **2. Which country has produced the most content?**

# %%
df['country'].value_counts().head(1)
# Out:
# country
# United States    2809
# Name: count, dtype: int64

# %% [markdown]
# ## **3. Filter all content released after 2018 that is rated TV-MA**

# %%
df[(df["rating"] == "TV-MA") & (df["release_year"] > 2018)]
# Out:
#      show_id     type                        title             director  \
# 1         s2  TV Show                Blood & Water              Unknown
# 2         s3  TV Show                    Ganglands      Julien Leclercq
# 3         s4  TV Show        Jailbirds New Orleans              Unknown
# 4         s5  TV Show                 Kota Factory              Unknown
# 5         s6  TV Show                Midnight Mass        Mike Flanagan
# ...      ...      ...                          ...                  ...
# 8437   s8438  TV Show       The Netflix Afterparty              Unknown
# 8516   s8517    Movie    The Spy Who Fell to Earth      Thomas Meadmore
# 8631   s8632    Movie  Trixie Mattel: Moving Parts  Nicholas Zeig-Owens
# 8718   s8719    Movie       Westside vs. the World        Michael Fahey
# 8756   s8757    Movie                    Woodstock        Barak Goodman
#
#                                                    cast         country  \
# ...

# %% [markdown]
# ## **4. Filter all Movies from India only**

# %%
df[(df["country"] == "India") & (df["type"] == "Movie")]
# Out:
#      show_id   type                  title                 director  \
# 24       s25  Movie                  Jeans               S. Shankar
# 105     s106  Movie       Angamaly Diaries     Lijo Jose Pellissery
# 114     s115  Movie                 Anjaam             Rahul Rawail
# 116     s117  Movie                 Dhanak          Nagesh Kukunoor
# 118     s119  Movie                Gurgaon            Shanker Raman
# ...      ...    ...                    ...                      ...
# 8772   s8773  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 8773   s8774  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 8798   s8799  Movie               Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800  Movie                  Zenda           Avadhoot Gupte
# 8806   s8807  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country date_added  \
# ...

# %% [markdown]
# ## **5. Filter titles where director contains the name "Shah"**

# %%
df[df["director"].str.contains("Shah")]
# Out:
#      show_id   type                          title             director  \
# 1410   s1411  Movie  Tribhanga - Tedhi Medhi Crazy       Renuka Shahane
# 2544   s2545  Movie                 Action Replayy  Vipul Amrutlal Shah
# 2644   s2645  Movie    Yours Sincerely, Kanan Gill         Neville Shah
# 2729   s2730  Movie                           Kaal           Soham Shah
# 3868   s3869  Movie                          Laatu           Manav Shah
# 4615   s4616  Movie       Zindagi Kitni Haseen Hay        Anjum Shahzad
# 4797   s4798  Movie                Namastey London  Vipul Amrutlal Shah
# 5482   s5483  Movie           Kabhi Haan Kabhi Naa          Kundan Shah
# 6610   s6611  Movie               Dil Hai Tumhaara          Kundan Shah
# 7247   s7248  Movie                      Kya Kehna          Kundan Shah
# 7688   s7689  Movie                    P Se PM Tak          Kundan Shah
#
#                                                    cast   country date_added  \
# ...

# %% [markdown]
# ## **6. What are the top 5 most common ratings in the dataset?**

# %%
df['rating'].value_counts().head(5)
# Out:
# rating
# TV-MA    3205
# TV-14    2157
# TV-PG     861
# R         799
# PG-13     490
# Name: count, dtype: int64

# %% [markdown]
# ## **7. Find the top 5 countries with most content (Movies + TV shows combined)**

# %%
df["country"].value_counts().head(5)
# Out:
# country
# United States     2809
# India              972
# Unknown            829
# United Kingdom     418
# Japan              243
# Name: count, dtype: int64

# %% [markdown]
# ## **8. Which year had the highest number of releases?**

# %%
df["release_year"].value_counts().head(1)
# Out:
# release_year
# 2018    1146
# Name: count, dtype: int64

# %% [markdown]
# ## **9.Create a new column duration_type — for Movies it should say Movie and for TV Shows it should say based**
# ## **on number of seasons (Hint: you'll need to look at the duration column format)**

# %%
df["duration_type"] =

# %% [markdown]
# ## **10. Filter all titles where genre (listed_in) contains the word "Comedy"**

# %%
df[df["listed_in"].str.contains("Comedy")]
# Out:
#      show_id     type                                              title  \
# 278     s279    Movie                        Lokillo: Nothing's the Same
# 359     s360    Movie                       The Original Kings of Comedy
# 388     s389  TV Show            Plastic Cup Boyz: Laughing My Mask Off!
# 400     s401  TV Show  Revelations: The Masters of the Universe: Reve...
# 475     s476    Movie                                       The Stand-Up
# ...      ...      ...                                                ...
# 7812   s7813  TV Show                                   Queens of Comedy
# 7813   s7814  TV Show                                   Queens vs. Kings
# 7908   s7909  TV Show                       Russell Peters vs. the World
# 7909   s7910    Movie                          Russell Peters: Notorious
# 8437   s8438  TV Show                             The Netflix Afterparty
#
#                              director  \
# 278                    Julián Gaviria
# ...

# %% [markdown]
# ## **11.Group by type and find average release_year for Movies vs TV Shows — which one is generally newer content?**

# %%
df.groupby("type")["release_year"].mean()
# Out:
# type
# Movie      2013.120144
# TV Show    2016.627628
# Name: release_year, dtype: float64
