# %%
import pandas as pd

# %%
df = pd.read_csv("employee_data.csv")
df
# Out:
#    EmployeeID     Name Department  Age  Salary  Experience       City  \
# 0        E101    Aarav         IT   25   60000           2       Pune
# 1        E102     Diya         HR   29   50000           4     Mumbai
# 2        E103    Rohan    Finance   35   75000           8      Delhi
# 3        E104    Meera         IT   28   62000           3       Pune
# 4        E105    Kabir  Marketing   32   58000           6  Bangalore
# 5        E106     Isha    Finance   41   82000          12     Mumbai
# 6        E107    Arjun         IT   30   67000           5  Hyderabad
# 7        E108     Sara         HR   26   48000           2       Pune
# 8        E109   Vivaan  Marketing   38   73000          10      Delhi
# 9        E110    Anaya    Finance   27   69000           4     Mumbai
# 10       E111  Reyansh         IT   33   71000           7  Bangalore
# 11       E112     Myra         HR   31   52000           6  Hyderabad
# ...

# %% [markdown]
# ### **1. Dataset Overview**

# %%
df.head()
# gives us the first 5 rows of dataset by defualt can be assigned whichever number of rows we want ex : df.head(3)
# Out:
#   EmployeeID   Name Department  Age  Salary  Experience       City  \
# 0       E101  Aarav         IT   25   60000           2       Pune
# 1       E102   Diya         HR   29   50000           4     Mumbai
# 2       E103  Rohan    Finance   35   75000           8      Delhi
# 3       E104  Meera         IT   28   62000           3       Pune
# 4       E105  Kabir  Marketing   32   58000           6  Bangalore
#
#    PerformanceScore
# 0                 3
# 1                 4
# 2                 5
# 3                 4
# 4                 3

# %%
df.head(3) #assigns us only the first 3 rows
# Out:
#   EmployeeID   Name Department  Age  Salary  Experience    City  \
# 0       E101  Aarav         IT   25   60000           2    Pune
# 1       E102   Diya         HR   29   50000           4  Mumbai
# 2       E103  Rohan    Finance   35   75000           8   Delhi
#
#    PerformanceScore
# 0                 3
# 1                 4
# 2                 5

# %%
df.describe()
# count : gives us total number of values that column has so we have a dataset of 30 values/rows so we get count same for all columns as 30.
# mean : then we get the average/mean of age , avg salary , avg experience of people working in that company and avg performance score.
# std : this tells is the standard deviation of
# Out:
#              Age        Salary  Experience  PerformanceScore
# count  30.000000     30.000000   30.000000         30.000000
# mean   32.000000  66200.000000    6.566667          4.066667
# std     5.051459  12084.187445    3.549486          0.784915
# min    24.000000  48000.000000    1.000000          3.000000
# 25%    28.000000  56500.000000    4.000000          3.250000
# 50%    31.000000  63500.000000    6.000000          4.000000
# 75%    35.750000  74500.000000    8.750000          5.000000
# max    42.000000  90000.000000   15.000000          5.000000
