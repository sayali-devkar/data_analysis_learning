# %%
import pandas as pd
from io import StringIO

data = """name,age,city,salary,department,experience
Rahul,28,Mumbai,55000,IT,3
Priya,34,Pune,72000,HR,8
Amit,,Delhi,48000,IT,2
Sneha,26,Bangalore,61000,Finance,4
Rohit,31,Mumbai,,IT,6
Kavya,29,Pune,53000,HR,4
Arjun,45,Delhi,95000,Finance,20
Neha,28,,67000,IT,5
Vikram,38,Mumbai,88000,HR,12
Pooja,24,Pune,42000,Finance,1
Kiran,,Bangalore,71000,IT,7
Rahul,33,Delhi,59000,,8
"""

df = pd.read_csv(StringIO(data))

# %%
df
# Out:
#       name   age       city   salary department  experience
# 0    Rahul  28.0     Mumbai  55000.0         IT           3
# 1    Priya  34.0       Pune  72000.0         HR           8
# 2     Amit   NaN      Delhi  48000.0         IT           2
# 3    Sneha  26.0  Bangalore  61000.0    Finance           4
# 4    Rohit  31.0     Mumbai      NaN         IT           6
# 5    Kavya  29.0       Pune  53000.0         HR           4
# 6    Arjun  45.0      Delhi  95000.0    Finance          20
# 7     Neha  28.0        NaN  67000.0         IT           5
# 8   Vikram  38.0     Mumbai  88000.0         HR          12
# 9    Pooja  24.0       Pune  42000.0    Finance           1
# 10   Kiran   NaN  Bangalore  71000.0         IT           7
# 11   Rahul  33.0      Delhi  59000.0        NaN           8

# %% [markdown]
# ### **Performing EDA**

# %%
#1)
df.shape # tells us that we have 12 rows and 6 columns in our dataset
# Out:
# (12, 6)

# %%
#2)
df.head() # defualt it is set to five rows but we can modify it according to our needs we can take 1 row or all rows
# Out:
#     name   age       city   salary department  experience
# 0  Rahul  28.0     Mumbai  55000.0         IT           3
# 1  Priya  34.0       Pune  72000.0         HR           8
# 2   Amit   NaN      Delhi  48000.0         IT           2
# 3  Sneha  26.0  Bangalore  61000.0    Finance           4
# 4  Rohit  31.0     Mumbai      NaN         IT           6

# %%
#3)
df.tail() #defualt it is set to five rows but we can modify it according to our needs we can take 1 row or all rows
# Out:
#       name   age       city   salary department  experience
# 7     Neha  28.0        NaN  67000.0         IT           5
# 8   Vikram  38.0     Mumbai  88000.0         HR          12
# 9    Pooja  24.0       Pune  42000.0    Finance           1
# 10   Kiran   NaN  Bangalore  71000.0         IT           7
# 11   Rahul  33.0      Delhi  59000.0        NaN           8

# %%
#4)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        12 non-null     str
#  1   age         10 non-null     float64
#  2   city        11 non-null     str
#  3   salary      11 non-null     float64
#  4   department  11 non-null     str
#  5   experience  12 non-null     int64
# dtypes: float64(2), int64(1), str(3)
# memory usage: 871.0 bytes

# %%
#5)
df.describe()
# Out:
#              age        salary  experience
# count  10.000000     11.000000   12.000000
# mean   31.600000  64636.363636    6.666667
# std     6.239658  16218.956361    5.175701
# min    24.000000  42000.000000    1.000000
# 25%    28.000000  54000.000000    3.750000
# 50%    30.000000  61000.000000    5.500000
# 75%    33.750000  71500.000000    8.000000
# max    45.000000  95000.000000   20.000000

# %%
#7)
df.columns
# Out:
# Index(['name', 'age', 'city', 'salary', 'department', 'experience'], dtype='str')

# %%
#8)
df.dtypes
# Out:
# name              str
# age           float64
# city              str
# salary        float64
# department        str
# experience      int64
# dtype: object

# %% [markdown]
# #### **HANDLING MISSING VALUES**

# %%
#9) 
df.isnull().sum()
# Out:
# name          0
# age           2
# city          1
# salary        1
# department    1
# experience    0
# dtype: int64

# %%
#10)
df["age"]=df["age"].fillna(df["age"].mean())
df  #age of  2nd and 10th value got replaced by mean of 10 values which is 31.6
# Out:
#       name   age       city   salary department  experience
# 0    Rahul  28.0     Mumbai  55000.0         IT           3
# 1    Priya  34.0       Pune  72000.0         HR           8
# 2     Amit  31.6      Delhi  48000.0         IT           2
# 3    Sneha  26.0  Bangalore  61000.0    Finance           4
# 4    Rohit  31.0     Mumbai      NaN         IT           6
# 5    Kavya  29.0       Pune  53000.0         HR           4
# 6    Arjun  45.0      Delhi  95000.0    Finance          20
# 7     Neha  28.0        NaN  67000.0         IT           5
# 8   Vikram  38.0     Mumbai  88000.0         HR          12
# 9    Pooja  24.0       Pune  42000.0    Finance           1
# 10   Kiran  31.6  Bangalore  71000.0         IT           7
# 11   Rahul  33.0      Delhi  59000.0        NaN           8

# %%
df["salary"] = df["salary"].fillna(df["salary"].median())
df
# Out:
#       name   age       city   salary department  experience
# 0    Rahul  28.0     Mumbai  55000.0         IT           3
# 1    Priya  34.0       Pune  72000.0         HR           8
# 2     Amit  31.6      Delhi  48000.0         IT           2
# 3    Sneha  26.0  Bangalore  61000.0    Finance           4
# 4    Rohit  31.0     Mumbai  61000.0         IT           6
# 5    Kavya  29.0       Pune  53000.0         HR           4
# 6    Arjun  45.0      Delhi  95000.0    Finance          20
# 7     Neha  28.0        NaN  67000.0         IT           5
# 8   Vikram  38.0     Mumbai  88000.0         HR          12
# 9    Pooja  24.0       Pune  42000.0    Finance           1
# 10   Kiran  31.6  Bangalore  71000.0         IT           7
# 11   Rahul  33.0      Delhi  59000.0        NaN           8

# %%
df["city"] = df["city"].fillna(df["city"].mode()[0])
df
# Out:
#       name   age       city   salary department  experience
# 0    Rahul  28.0     Mumbai  55000.0         IT           3
# 1    Priya  34.0       Pune  72000.0         HR           8
# 2     Amit  31.6      Delhi  48000.0         IT           2
# 3    Sneha  26.0  Bangalore  61000.0    Finance           4
# 4    Rohit  31.0     Mumbai  61000.0         IT           6
# 5    Kavya  29.0       Pune  53000.0         HR           4
# 6    Arjun  45.0      Delhi  95000.0    Finance          20
# 7     Neha  28.0      Delhi  67000.0         IT           5
# 8   Vikram  38.0     Mumbai  88000.0         HR          12
# 9    Pooja  24.0       Pune  42000.0    Finance           1
# 10   Kiran  31.6  Bangalore  71000.0         IT           7
# 11   Rahul  33.0      Delhi  59000.0        NaN           8

# %%
print(df["city"].mode())
# Out:
# 0    Delhi
# Name: city, dtype: str

# %%
df["department"] = df["department"].fillna("Unknown")
df
# Out:
#       name   age       city   salary department  experience
# 0    Rahul  28.0     Mumbai  55000.0         IT           3
# 1    Priya  34.0       Pune  72000.0         HR           8
# 2     Amit  31.6      Delhi  48000.0         IT           2
# 3    Sneha  26.0  Bangalore  61000.0    Finance           4
# 4    Rohit  31.0     Mumbai  61000.0         IT           6
# 5    Kavya  29.0       Pune  53000.0         HR           4
# 6    Arjun  45.0      Delhi  95000.0    Finance          20
# 7     Neha  28.0      Delhi  67000.0         IT           5
# 8   Vikram  38.0     Mumbai  88000.0         HR          12
# 9    Pooja  24.0       Pune  42000.0    Finance           1
# 10   Kiran  31.6  Bangalore  71000.0         IT           7
# 11   Rahul  33.0      Delhi  59000.0    Unknown           8

# %%
df.dropna(subset = ["salary"])
df
# Out:
#       name   age       city   salary department  experience
# 0    Rahul  28.0     Mumbai  55000.0         IT           3
# 1    Priya  34.0       Pune  72000.0         HR           8
# 2     Amit  31.6      Delhi  48000.0         IT           2
# 3    Sneha  26.0  Bangalore  61000.0    Finance           4
# 4    Rohit  31.0     Mumbai  61000.0         IT           6
# 5    Kavya  29.0       Pune  53000.0         HR           4
# 6    Arjun  45.0      Delhi  95000.0    Finance          20
# 7     Neha  28.0      Delhi  67000.0         IT           5
# 8   Vikram  38.0     Mumbai  88000.0         HR          12
# 9    Pooja  24.0       Pune  42000.0    Finance           1
# 10   Kiran  31.6  Bangalore  71000.0         IT           7
# 11   Rahul  33.0      Delhi  59000.0    Unknown           8

# %%
df.isnull().sum()/len(df)*100
# Out:
# name          0.0
# age           0.0
# city          0.0
# salary        0.0
# department    0.0
# experience    0.0
# dtype: float64

# %%
df.dropna(subset=["salary"])
# Out:
#       name   age       city   salary department  experience
# 0    Rahul  28.0     Mumbai  55000.0         IT           3
# 1    Priya  34.0       Pune  72000.0         HR           8
# 2     Amit  31.6      Delhi  48000.0         IT           2
# 3    Sneha  26.0  Bangalore  61000.0    Finance           4
# 4    Rohit  31.0     Mumbai  61000.0         IT           6
# 5    Kavya  29.0       Pune  53000.0         HR           4
# 6    Arjun  45.0      Delhi  95000.0    Finance          20
# 7     Neha  28.0      Delhi  67000.0         IT           5
# 8   Vikram  38.0     Mumbai  88000.0         HR          12
# 9    Pooja  24.0       Pune  42000.0    Finance           1
# 10   Kiran  31.6  Bangalore  71000.0         IT           7
# 11   Rahul  33.0      Delhi  59000.0    Unknown           8

# %% [raw]
# # practice before moving to filtering
# check shape, info, describe
# find null %
# fill age with mean
# drop rows where department is null

# %% [raw]
# df.shape
# df.info()
# df.describe()
# df.isnull().sum()/len(df)*100
# df["age"] = df["age"].fillna(df["age"].mean())
# df.dropna(subset = ["department"])

# %% [markdown]
# #### **Filtering**

# %% [raw]
# show only IT department employees
# show employees with salary > 60000
# show employees from Pune with experience > 3
# select only name, salary, department columns

# %%
df[df["department"] == "IT"]
# Out:
#      name   age       city   salary department  experience
# 0   Rahul  28.0     Mumbai  55000.0         IT           3
# 2    Amit  31.6      Delhi  48000.0         IT           2
# 4   Rohit  31.0     Mumbai  61000.0         IT           6
# 7    Neha  28.0      Delhi  67000.0         IT           5
# 10  Kiran  31.6  Bangalore  71000.0         IT           7

# %%
df[df["salary"] > 60000]
# Out:
#       name   age       city   salary department  experience
# 1    Priya  34.0       Pune  72000.0         HR           8
# 3    Sneha  26.0  Bangalore  61000.0    Finance           4
# 4    Rohit  31.0     Mumbai  61000.0         IT           6
# 6    Arjun  45.0      Delhi  95000.0    Finance          20
# 7     Neha  28.0      Delhi  67000.0         IT           5
# 8   Vikram  38.0     Mumbai  88000.0         HR          12
# 10   Kiran  31.6  Bangalore  71000.0         IT           7

# %%
df[(df["city"] == "Pune") & (df["experience"] > 3)]
# Out:
#     name   age  city   salary department  experience
# 1  Priya  34.0  Pune  72000.0         HR           8
# 5  Kavya  29.0  Pune  53000.0         HR           4

# %%
df[["name","salary","department"]]
# Out:
#       name   salary department
# 0    Rahul  55000.0         IT
# 1    Priya  72000.0         HR
# 2     Amit  48000.0         IT
# 3    Sneha  61000.0    Finance
# 4    Rohit  61000.0         IT
# 5    Kavya  53000.0         HR
# 6    Arjun  95000.0    Finance
# 7     Neha  67000.0         IT
# 8   Vikram  88000.0         HR
# 9    Pooja  42000.0    Finance
# 10   Kiran  71000.0         IT
# 11   Rahul  59000.0    Unknown

# %% [raw]
# 1. show only Finance department employees
# 2. show employees with experience >= 5
# 3. show employees from Mumbai OR Delhi
# 4. show employees where salary is between 50000 and 80000
# 5. show only name and city of HR department employees

# %%
df[df["department"] == "Finance"]
# Out:
#     name   age       city   salary department  experience
# 3  Sneha  26.0  Bangalore  61000.0    Finance           4
# 6  Arjun  45.0      Delhi  95000.0    Finance          20
# 9  Pooja  24.0       Pune  42000.0    Finance           1

# %%
df[df["experience"] >= 5]
# Out:
#       name   age       city   salary department  experience
# 1    Priya  34.0       Pune  72000.0         HR           8
# 4    Rohit  31.0     Mumbai  61000.0         IT           6
# 6    Arjun  45.0      Delhi  95000.0    Finance          20
# 7     Neha  28.0      Delhi  67000.0         IT           5
# 8   Vikram  38.0     Mumbai  88000.0         HR          12
# 10   Kiran  31.6  Bangalore  71000.0         IT           7
# 11   Rahul  33.0      Delhi  59000.0    Unknown           8

# %%
df[(df["city"] == "Mumbai") | (df["city"] == "Delhi")]
# Out:
#       name   age    city   salary department  experience
# 0    Rahul  28.0  Mumbai  55000.0         IT           3
# 2     Amit  31.6   Delhi  48000.0         IT           2
# 4    Rohit  31.0  Mumbai  61000.0         IT           6
# 6    Arjun  45.0   Delhi  95000.0    Finance          20
# 7     Neha  28.0   Delhi  67000.0         IT           5
# 8   Vikram  38.0  Mumbai  88000.0         HR          12
# 11   Rahul  33.0   Delhi  59000.0    Unknown           8

# %%
df[(df["salary"] >= 50000) & (df["salary"] <= 80000)]
# Out:
#      name   age       city   salary department  experience
# 0   Rahul  28.0     Mumbai  55000.0         IT           3
# 1   Priya  34.0       Pune  72000.0         HR           8
# 3   Sneha  26.0  Bangalore  61000.0    Finance           4
# 4   Rohit  31.0     Mumbai  61000.0         IT           6
# 5   Kavya  29.0       Pune  53000.0         HR           4
# 7    Neha  28.0      Delhi  67000.0         IT           5
# 10  Kiran  31.6  Bangalore  71000.0         IT           7
# 11  Rahul  33.0      Delhi  59000.0    Unknown           8

# %%
df[df["department"]=="HR"][["name","city"]]
# Out:
#      name    city
# 1   Priya    Pune
# 5   Kavya    Pune
# 8  Vikram  Mumbai
