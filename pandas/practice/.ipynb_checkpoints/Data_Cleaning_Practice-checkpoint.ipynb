# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('messy_orders_practice.csv')

# %% [markdown]
# ## **1. DATA CLEANING**

# %%
df.head()
# Out:
#    OrderID   OrderDate CustomerCity     Status  Qty  PricePerUnit  Amount  \
# 0     5089  15-01-2024    Ahmedabad  Delivered    5           499  2495.0
# 1     5127  26/06/2024        DELHI  Delivered    6           299  1794.0
# 2     5046  2024-02-28         PUNE  Delivered    6           999  5994.0
# 3     5012  24-05-2024      chennai  Delivered    4           299  1196.0
# 4     5053  01-02-2024    Ahmedabad   Returned    5           199   995.0
#
#    DeliveryDays       PaymentMode Country IsPrimeMember PrimeDeliveryType  \
# 0           2.0  Cash on Delivery   India           Yes           One-Day
# 1           9.0       Net Banking   India            No               NaN
# 2           8.0               UPI   India           Yes           One-Day
# 3           8.0               UPI   India           Yes           One-Day
# 4           7.0       Net Banking   India            No               NaN
#
#    Unnamed: 12
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
df.shape
# Out:
# (154, 13)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   OrderID            154 non-null    int64
#  1   OrderDate          154 non-null    str
#  2   CustomerCity       154 non-null    str
#  3   Status             154 non-null    str
#  4   Qty                154 non-null    int64
#  5   PricePerUnit       154 non-null    int64
#  6   Amount             119 non-null    float64
#  7   DeliveryDays       105 non-null    float64
#  8   PaymentMode        150 non-null    str
#  9   Country            154 non-null    str
#  10  IsPrimeMember      154 non-null    str
#  11  PrimeDeliveryType  83 non-null     str
#  12  Unnamed: 12        0 non-null      float64
# dtypes: float64(3), int64(3), str(7)
# memory usage: 22.9 KB

# %%
df.isnull().sum()
# Out:
# OrderID                0
# OrderDate              0
# CustomerCity           0
# Status                 0
# Qty                    0
# PricePerUnit           0
# Amount                35
# DeliveryDays          49
# PaymentMode            4
# Country                0
# IsPrimeMember          0
# PrimeDeliveryType     71
# Unnamed: 12          154
# dtype: int64

# %%
df['OrderDate'].head(10)
# Out:
# 0    15-01-2024
# 1    26/06/2024
# 2    2024-02-28
# 3    24-05-2024
# 4    01-02-2024
# 5    2024-02-12
# 6    2024-02-24
# 7    16-05-2024
# 8    2024-07-20
# 9    06-05-2024
# Name: OrderDate, dtype: str

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate'], format='mixed', dayfirst=True)

# %%
df['OrderDate'].dtype
df['OrderDate'].head(20)
# Out:
# 0    2024-01-15
# 1    2024-06-26
# 2    2024-02-28
# 3    2024-05-24
# 4    2024-02-01
# 5    2024-12-02
# 6    2024-02-24
# 7    2024-05-16
# 8    2024-07-20
# 9    2024-05-06
# 10   2024-02-01
# 11   2024-10-19
# 12   2024-04-03
# 13   2024-08-18
# 14   2024-04-22
# 15   2024-05-01
# 16   2024-04-13
# 17   2024-08-13
# 18   2024-02-17
# 19   2024-06-08
# Name: OrderDate, dtype: datetime64[us]

# %%
df.duplicated().sum()
# Out:
# np.int64(4)

# %%
df[df.duplicated()]
# Out:
#      OrderID  OrderDate CustomerCity     Status  Qty  PricePerUnit  Amount  \
# 71      5015 2024-05-06         pune  Cancelled    2          1499     NaN
# 113     5017 2024-12-03    Bangalore  Delivered    5           999  4995.0
# 137     5076 2024-05-19      CHENNAI  Delivered    2          1999  3998.0
# 151     5099 2024-01-15      CHENNAI  Cancelled    6          1499     NaN
#
#      DeliveryDays       PaymentMode Country IsPrimeMember PrimeDeliveryType  \
# 71            NaN  Cash on Delivery   India            No               NaN
# 113           4.0       Net Banking   India           Yes           One-Day
# 137           5.0       Net Banking   India           Yes           One-Day
# 151           NaN               UPI   India            No               NaN
#
#      Unnamed: 12
# 71           NaN
# 113          NaN
# 137          NaN
# 151          NaN

# %%
df = df.drop_duplicates()
df.duplicated().sum()
df.shape
# Out:
# (150, 13)

# %%
df.nunique()
# Out:
# OrderID              150
# OrderDate            121
# CustomerCity          28
# Status                 4
# Qty                    6
# PricePerUnit           7
# Amount                40
# DeliveryDays          10
# PaymentMode            5
# Country                1
# IsPrimeMember          2
# PrimeDeliveryType      1
# Unnamed: 12            0
# dtype: int64

# %%
df.groupby('IsPrimeMember')['PrimeDeliveryType'].value_counts(dropna=False)
# Out:
# IsPrimeMember  PrimeDeliveryType
# No             NaN                  69
# Yes            One-Day              81
# Name: count, dtype: int64

# %%
df = df.drop(columns=['Country', 'Unnamed: 12', 'PrimeDeliveryType'])

# %%
df.columns.tolist()
# Out:
# ['OrderID',
#  'OrderDate',
#  'CustomerCity',
#  'Status',
#  'Qty',
#  'PricePerUnit',
#  'Amount',
#  'DeliveryDays',
#  'PaymentMode',
#  'IsPrimeMember']

# %%
df[df['Amount'].isnull()]['Status'].value_counts()
# Out:
# Status
# Cancelled    33
# Name: count, dtype: int64

# %%
df[df['DeliveryDays'].isnull()]['Status'].value_counts()
# Out:
# Status
# Cancelled    33
# Pending      14
# Name: count, dtype: int64

# %%
df['DeliveryDays'].dtype
# Out:
# dtype('float64')

# %%
df[df['PaymentMode'].isnull()]['Status'].value_counts()
# Out:
# Status
# Delivered    2
# Cancelled    2
# Name: count, dtype: int64

# %%
df['PaymentMode'] = df['PaymentMode'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# OrderID           0
# OrderDate         0
# CustomerCity      0
# Status            0
# Qty               0
# PricePerUnit      0
# Amount           33
# DeliveryDays     47
# PaymentMode       0
# IsPrimeMember     0
# dtype: int64

# %% [markdown]
# ## **2. EDA**

# %% [markdown]
# ### **A)Do Prime members have a higher average order value than non-Prime members?**

# %%
prime_avg_spend = df.groupby('IsPrimeMember')['Amount'].mean()
prime_avg_spend
# Out:
# IsPrimeMember
# No     2972.481481
# Yes    3175.730159
# Name: Amount, dtype: float64

# %%
df['IsPrimeMember'].value_counts()
# Out:
# IsPrimeMember
# Yes    81
# No     69
# Name: count, dtype: int64

# %% [markdown]
# ### **INSIGHT**
# - Prime members show a higher average order value (₹3,175.73) compared to non-Prime members (₹2,972.48) — a difference of ~₹203, or about 6.3%. With a reasonably balanced sample size (81 Prime vs 69 non-Prime orders), this difference appears to be a genuine pattern rather than a small-sample artifact, suggesting Prime membership may be associated with modestly higher spending per order

# %% [markdown]
# #### **B)Delivery Time Per City**

# %%
df['CustomerCity'].unique()
# Out:
# <ArrowStringArray>
# ['Ahmedabad',     'DELHI',      'PUNE',   'chennai',   'Chennai',   'KOLKATA',
#  'Hyderabad',      'pune',    'Madras',   'Kolkata',     'Delhi', 'bangalore',
#   'Calcutta', 'Bangalore', 'ahmedabad',    'mumbai',      'Pune',   'CHENNAI',
#     'Bombay',    'MUMBAI',     'delhi', 'HYDERABAD', 'hyderabad', 'Bengaluru',
#  'BANGALORE', 'New Delhi',    'Mumbai', 'AHMEDABAD']
# Length: 28, dtype: str

# %% [markdown]
# ### Data Cleaning task
# - So here we have a issue that there are some cities which are same and have names in lower and upper cases
# - Also there are some cities which have there old name and new name together which will cause an issue in the insight

# %%
df['CustomerCity'] = df['CustomerCity'].str.title()

# %%
df['CustomerCity'].unique()
# Out:
# <ArrowStringArray>
# ['Ahmedabad',     'Delhi',      'Pune',   'Chennai',   'Kolkata', 'Hyderabad',
#     'Madras', 'Bangalore',  'Calcutta',    'Mumbai',    'Bombay', 'Bengaluru',
#  'New Delhi']
# Length: 13, dtype: str

# %%
# map the alternate names to their modern/standard name, using a dictionary + .replace():
city_mapping = {
    'Madras': 'Chennai',
    'Calcutta': 'Kolkata',
    'Bombay': 'Mumbai',
    'Bengaluru': 'Bangalore',
    'New Delhi': 'Delhi',
}
df['CustomerCity'] = df['CustomerCity'].replace(city_mapping)

# %%
df['CustomerCity'].unique()
# Out:
# <ArrowStringArray>
# ['Ahmedabad',     'Delhi',      'Pune',   'Chennai',   'Kolkata', 'Hyderabad',
#  'Bangalore',    'Mumbai']
# Length: 8, dtype: str

# %%
delivery_time = df.groupby('CustomerCity')['DeliveryDays'].mean()
delivery_time = delivery_time.sort_values(ascending=False)
plt.bar(delivery_time.index , delivery_time.values , color = '#9C5748')
plt.xlabel('City')
plt.ylabel('Delivery Days')
plt.title('Delivery Time Per City')
plt.tight_layout()
plt.xticks(rotation = 40 , ha = 'right')
plt.show()
