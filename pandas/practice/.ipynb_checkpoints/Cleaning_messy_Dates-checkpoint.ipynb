# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("employee_dataset.csv")
df
# Out:
#    Employee_ID   Employee_Name  Gender Joining_Date   Salary Department
# 0          101    Rahul Sharma       M   15/03/2023  ₹45,000         IT
# 1          102     Priya Patil  Female   2023-04-20  ₹52,500         HR
# 2          103      Amit Kumar    Male  May 12 2022  ₹60,000    Finance
# 3          104      Neha Joshi  Female          NaN  ₹48,000         IT
# 4          105     Rohan Gupta    Male   31/02/2023  ₹55,000      Sales
# 5          106  Sneha Kulkarni  Female     20230515  ₹62,500         HR
# 6          107  Sneha Kulkarni  Female     20230515  ₹62,500         HR
# 7          108      Kiran Naik  Female   18-08-2021  ₹58,000    Finance

# %% [markdown]
# # **DATA CLEANING**

# %% [markdown]
# ### **1.String Mapping**

# %%
df['Gender'] = df['Gender'].replace({'M' :'Male'})
df
# Out:
#    Employee_ID   Employee_Name  Gender Joining_Date   Salary Department
# 0          101    Rahul Sharma    Male   15/03/2023  ₹45,000         IT
# 1          102     Priya Patil  Female   2023-04-20  ₹52,500         HR
# 2          103      Amit Kumar    Male  May 12 2022  ₹60,000    Finance
# 3          104      Neha Joshi  Female          NaN  ₹48,000         IT
# 4          105     Rohan Gupta    Male   31/02/2023  ₹55,000      Sales
# 5          106  Sneha Kulkarni  Female     20230515  ₹62,500         HR
# 6          107  Sneha Kulkarni  Female     20230515  ₹62,500         HR
# 7          108      Kiran Naik  Female   18-08-2021  ₹58,000    Finance

# %% [markdown]
# ### **2.Removing Duplicates**

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#    Employee_ID   Employee_Name  Gender Joining_Date   Salary Department
# 0          101    Rahul Sharma    Male   15/03/2023  ₹45,000         IT
# 1          102     Priya Patil  Female   2023-04-20  ₹52,500         HR
# 2          103      Amit Kumar    Male  May 12 2022  ₹60,000    Finance
# 3          104      Neha Joshi  Female          NaN  ₹48,000         IT
# 4          105     Rohan Gupta    Male   31/02/2023  ₹55,000      Sales
# 5          106  Sneha Kulkarni  Female     20230515  ₹62,500         HR
# 6          107  Sneha Kulkarni  Female     20230515  ₹62,500         HR
# 7          108      Kiran Naik  Female   18-08-2021  ₹58,000    Finance

# %%
df.drop_duplicates(subset=["Employee_Name"], inplace=True)

# %%
df
# Out:
#    Employee_ID   Employee_Name  Gender Joining_Date   Salary Department
# 0          101    Rahul Sharma    Male   15/03/2023  ₹45,000         IT
# 1          102     Priya Patil  Female   2023-04-20  ₹52,500         HR
# 2          103      Amit Kumar    Male  May 12 2022  ₹60,000    Finance
# 3          104      Neha Joshi  Female          NaN  ₹48,000         IT
# 4          105     Rohan Gupta    Male   31/02/2023  ₹55,000      Sales
# 5          106  Sneha Kulkarni  Female     20230515  ₹62,500         HR
# 7          108      Kiran Naik  Female   18-08-2021  ₹58,000    Finance

# %% [markdown]
# ### **3.Fixing Salary**

# %%
df['Salary'] = df['Salary'].str.replace('₹' , "" , regex = False).str.replace(',' , '' , regex = False)
df
# Out:
#    Employee_ID   Employee_Name  Gender Joining_Date Salary Department
# 0          101    Rahul Sharma    Male   15/03/2023  45000         IT
# 1          102     Priya Patil  Female   2023-04-20  52500         HR
# 2          103      Amit Kumar    Male  May 12 2022  60000    Finance
# 3          104      Neha Joshi  Female          NaN  48000         IT
# 4          105     Rohan Gupta    Male   31/02/2023  55000      Sales
# 5          106  Sneha Kulkarni  Female     20230515  62500         HR
# 7          108      Kiran Naik  Female   18-08-2021  58000    Finance

# %%
df["Salary"] = df["Salary"].astype(int)

# %% [markdown]
# ### **4.Fixing Dates**

# %%
df['Joining_Date'] = pd.to_datetime(df["Joining_Date"], format = 'mixed' , errors = 'coerce')
df
# Out:
#    Employee_ID   Employee_Name  Gender Joining_Date  Salary Department
# 0          101    Rahul Sharma    Male   2023-03-15   45000         IT
# 1          102     Priya Patil  Female   2023-04-20   52500         HR
# 2          103      Amit Kumar    Male   2022-05-12   60000    Finance
# 3          104      Neha Joshi  Female          NaT   48000         IT
# 4          105     Rohan Gupta    Male          NaT   55000      Sales
# 5          106  Sneha Kulkarni  Female   2023-05-15   62500         HR
# 7          108      Kiran Naik  Female   2021-08-18   58000    Finance

# %% [markdown]
# # **VISUALIZATION**

# %% [markdown]
# ### **1.Average Salary By Department**

# %%
avg_salary = df.groupby('Department')['Salary'].mean()
avg_salary
# Out:
# Department
# Finance    59000.0
# HR         57500.0
# IT         46500.0
# Sales      55000.0
# Name: Salary, dtype: float64

# %%
plt.bar(avg_salary.index , avg_salary.values , color = "#994B68")
plt.xlabel("Department")
plt.ylabel("Salary")
plt.title("Average Salary By Department")
plt.show()

# %% [markdown]
# ### **2.How many employees are there in each department?**

# %%
employee_count = df.groupby("Department")["Employee_Name"].count()
employee_count
# Out:
# Department
# Finance    2
# HR         2
# IT         2
# Sales      1
# Name: Employee_Name, dtype: int64

# %%
plt.bar(employee_count.index , employee_count.values ,color = "#EDDFDF")
plt.xlabel("Department")
plt.ylabel("No.of employees")
plt.title("How many employees are there in each department")
plt.show()

# %% [markdown]
# ### **INSIGHT**
# - HR , IT AND FINANCE HAVE EQUAL NUMBER OF EMPLOYEES WHEREAS SALES HAS THE LEAST NUMBER OF EMPLOYEES.
