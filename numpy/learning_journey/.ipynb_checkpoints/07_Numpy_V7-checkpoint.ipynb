# %% [markdown]
# ## **Built in Mathematical Functions in Numpy**

# %% [markdown]
# ### 1. np.mean() - computes mean of an array
# np.mean(arr)

# %% [markdown]
# ### 2. np.std() - standard deviation
# np.std(arr)

# %% [markdown]
# ### 3. np.var() - computed variance
# np.var(arr)

# %% [markdown]
# ### 4. np.min() - minimum value form arr
# np.min(arr)

# %% [markdown]
# ### 5. np.max() - maximum value form arr
# np.max(arr)

# %% [markdown]
# ### 6. np.sum - sum of elements of array
# np.sum(arr)

# %% [markdown]
# ### 7. np.prod - product of elements of array
# np.prod(arr)

# %% [markdown]
# ### 8. np.median() -
# np.median(arr)

# %% [markdown]
# ### 9.np.percentile()

# %% [markdown]
# ### 10. np.argmin() - return the index of minimum value in array

# %% [markdown]
# ### 11. np.argmax() - return the index of maximum value in array.

# %% [markdown]
# ### 12. np.corrcoef() - coefficient correlation of

# %% [markdown]
# ### 13. np.unique() - unique elem form arr

# %% [markdown]
# ### 14. np.diff() - compute the nth diff of an array

# %% [markdown]
# ### 15. np.cumcum() - cumulativesum of an array.

# %% [markdown]
# ### 16. np.linspace() - arr with evenly spaced numbers

# %% [markdown]
# ### 17. np.log() - natural logarithm of an array

# %% [markdown]
# ### 18. np.exp() - exponential of array
