# %% [markdown]
# ### QUESTION 1

# %% [raw]
# Q1 Blood pressure range is 120-129 accepted as normal.
# Write a python program to verify the range of value from user.

# %%
bp = int(input("Enter Your Blood Pressure : "))
if 120 <= bp <=129 :
    print("Bp is Normal")
else:
    print("Urgent Medical Attention Needed")
# Out:
# Enter Your Blood Pressure :  119
# Urgent Medical Attention Needed

# %%
bp = int(input("Enter Your Blood Pressure : "))
if 120 <= bp <=129 :
    print("Bp is Normal")
else:
    print("Urgent Medical Attention Needed")
# Out:
# Enter Your Blood Pressure :  125
# Bp is Normal

# %%
bp = int(input("Enter Your Blood Pressure : "))
if 120 <= bp <=129 :
    print(f"{bp} comes under an normal bp range.")
else:
    print(f"Your entered BP is {bp}.This will need an medical attention")
# Out:
# Enter Your Blood Pressure :  144
# Your entered BP is 144.This will need an medical attention

# %% [markdown]
# ### Question 2

# %% [raw]
# Q2 Take input from user and check if number is even or odd.

# %%
num = int(input("Enter the number : "))
if num % 2 == 0 : 
    print(f"{num} is an Even Number")
else:
    print(f"{num} is an Odd Number")
# Out:
# Enter the number :  23
# 23 is an Odd Number

# %% [markdown]
# - Another approach :-->

# %%
num = int(input("Enter the number : "))
if num % 2 != 0 :                         
    print(f"{num} is an Odd Number")
else:
    print(f"{num} is an Even Number")
# Out:
# Enter the number :  4447483232
# 4447483232 is an Even Number
