# %% [markdown]
# ### Bollean

# %%
on = True

# %%
off = False

# %%
type(on)
# Out:
# bool

# %%
isinstance(off , bool)
# Out:
# True

# %%
a = 20
isinstance(a,bool)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(-23)
# Out:
# True

# %% [raw]
# Anything apart from 0 is true

# %%
bool(500)
# Out:
# True

# %%
bool(-500)
# Out:
# True

# %% [markdown]
# ### String

# %% [markdown]
# - String is a sequence of charachters
# - space is includedin string
# - always enclosed by sigle , double or triple qoutes."" , '', """ """

# %%
text = "We are learning data types today."
print(text)
# Out:
# We are learning data types today.

# %%
text = 'My name is "Sayali". I am learning "DS"'
print(text)
# Out:
# My name is "Sayali". I am learning "DS"

# %%
text = """ I am 'Sayali'.This is me Shining."""
print(text)
# Out:
#  I am 'Sayali'.This is me Shining.

# %%
print("Type of String is :",type(text))
# Out:
# Type of String is : <class 'str'>

# %% [markdown]
# ### Slicing

# %%
s = "PYTHON"
print(s[0])
print(s[1])
print(s[2])
print(s[3])
print(s[4])
print(s[5])
# Out:
# P
# Y
# T
# H
# O
# N

# %%
g = "Data Science"
print(g[4])
len(g)
print(g[11])
# Out:
#
# e

# %%
s = "Machine Learning"

# %%
s[0:7]
# Out:
# 'Machine'

# %%
s[8:]
# Out:
# 'Learning'

# %%
s[:7]
# Out:
# 'Machine'

# %%
s[-8:]
# Out:
# 'Learning'

# %%
s[::2]
# Out:
# 'McieLann'

# %%
s[7:0:-1]
# here zero is excluded which meanss dont take 0th position charachter.
# Out:
# ' enihca'

# %%
s[7::-1]
# here zero is included which means go till the end by default.
# Out:
# ' enihcaM'

# %% [markdown]
# ## partition() splits a string into 3 parts

# %% [raw]
# Before, Separator, After

# %%
text = "Data-Science"
text.partition("-")
# Out:
# ('Data', '-', 'Science')
