# %% [markdown]
# # CEll types

# %% [markdown]
# ### cell types

# %% [raw]
# markdown
# code
# raw text
# bullets

# %%
a = 10

# %% [raw]
# code cell is a default cell type

# %% [markdown]
# # Short Cuts

# %% [raw]
# 1.shift + enter = to run the cell and go in next cell.
# COMMAND MODE
# 2.hit "a" on keyboard to add a cell above.
# 3.hit "b" on keyboard to add a cell below.
# 4.dd : delete cell
# 5. ctrl+Z undo results.
# 6. r : convert cell to raw
# 7. y : convert cell to code
# 8. m : cnvert cell to markdown
# 9. c : copy
# 10  v : paste below
# 11  x : cut a cell

# %% [raw]
# EDIT MODE :
# CTRL+C = COPY
# CTRL+V = PASTE A TEXT
# CTRL+X = CUT A TEXT
# CTRL+Z = UNDO

# %% [markdown]
# # KEYWORDS

# %% [raw]
# KEYWORDS ARE RESERVED WORDS IN PYTHON CANNOT BE USED AS IDENTIFIRES IN PYTHON

# %%
a = 10 
print(id(a))
# Out:
# 140704578577608

# %%
b = 10   # WHEN NUMBER IS SAME TILL 256 AND STORED IN SAME LOCATION
print(id(b))
# HERRE BOTH THE NUMBERS ARE SAME I.E 10 SO THEY ARE STORED IN SAME MEMORY LOCATION
# Out:
# 140704578577608

# %%
a = 256 
print(id(a))
# Out:
# 140704578585480

# %%
b = 256 
print(id(b))
# Out:
# 140704578585480

# %%
import keyword
print(keyword.kwlist) #Listing out keywords
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
if = 100
# Out:
#   Cell In[15], line 1
#     if = 100
#        ^
# SyntaxError: invalid syntax

# %%
If = 100

# %% [markdown]
# ## IDENTIFIERS

# %% [markdown]
# - AN IDENTIFIER IS THE NAME THAT WE PROVIDE TO AN ENTITY SUCH AS FUNCTUION OR VARIABLE
# - IT HELPS IN SEPARATING ENTITY

# %% [markdown]
# ### 1 IDENTIFIER CANNOT START WTH NUMBER

# %%
1a = 100
# Out:
#   Cell In[17], line 1
#     1a = 100
#     ^
# SyntaxError: invalid decimal literal

# %%
a1 = 100

# %% [markdown]
# ### KEYWORDS CANNOT BE USED AS IDENTIFIERS

# %%
if = 100
# Out:
#   Cell In[20], line 1
#     if = 100
#        ^
# SyntaxError: invalid syntax

# %%
If = 100

# %% [markdown]
# ### special symbols are not allowed only underscored can be used

# %%
a@ = 100
# Out:
#   Cell In[22], line 1
#     a@ = 100
#        ^
# SyntaxError: invalid syntax

# %%
abc_ = 78
